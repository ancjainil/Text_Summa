# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
import sentencepiece as spm
# Out:
# 2022-04-06 17:51:14.755759: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-06 17:51:14.755787: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path = Path('/home/jazzyy/Text_Summ/language-model')

# %%
from inltk.tokenizer import GujaratiTokenizer

# %%
sp = spm.SentencePieceProcessor()
sp.Load(str(path/"../Tokenization/gujarati_lm.model"))
itos = [sp.IdToPiece(int(i)) for i in range(20000)]

# %%
itos
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '▁',
#  '.',
#  ',',
#  '▁છે',
#  '▁અને',
#  'ની',
#  'ના',
#  'માં',
#  '▁આ',
#  'ને',
#  '▁જ',
#  '▁એક',
#  'નો',
#  '▁આવેલા',
#  '▁તેમ',
#  'નું',
#  '▁કે',
#  '▁ગામમાં',
#  'થી',
#  '▁માટે',
#  '▁પણ',
#  '▁ખેતી',
#  '▁આવે',
#  '▁કરવામાં',
#  '▁તે',
#  '▁ભાગમાં',
#  '-',
#  'ો',
#  'ે',
#  '▁હતી',
#  '�.',
#  '▁પર',
#  'ી',
#  '▁જે',
#  '▁હતા',
#  '▁ગામ',
#  '▁ભારત',
#  '▁મુખ્ય',
#  'એ',
#  '▁હતો',
#  'X',
#  '▁આવેલું',
#  '▁ગુજરાત',
#  '▁હતું',
#  '▁એ',
#  '▁સાથે',
#  '▁કરી',
#  '▁પશ્ચિમ',
#  '▁રાજ્યના',
#  '▁દેશના',
#  '▁ડેરી',
#  '▁શાળા',
#  '▁મુખ્યત્વે',
#  '▁અન્ય',
#  '▁જેવી',
#  '▁પ્રાથમિક',
#  'ં',
#  'દૂધની',
#  '▁તરીકે',
#  '▁હોય',
#  '▁ગામના',
#  '▁પશુપાલન',
#  '▁દ્વારા',
#  '▁ખેતમજૂરી',
#  '▁આંગણવાડી',
#  '▁વ્યવસાય',
#  '▁પંચાયતઘર',
#  '▁પ્રાપ્ય',
#  '▁સવલતો',
#  '▁કરે',
#  '▁લોકોનો',
#  '▁તાલુકામાં',
#  '▁જિલ્લામાં',
#  '▁પાક',
#  '▁થયેલી',
#  'ા',
#  'સ',
#  '▁થાય',
#  '�',
#  '▁શાકભાજીના',
#  '▁કુલ',
#  'ર',
#  '▁તેઓ',
#  '▁એવા',
#  'ક',
#  'ન',
#  '▁���',
#  '▁રીતે',
#  '▁��',
#  '▁બાજરી',
#  '▁"',
#  'લ',
#  '▁લોકો',
#  '▁પૈકીના',
#  '▁તેમણે',
#  '▁કપાસ',
#  '▁તેના',
#  '"',
#  '▁તાલુકાઓ',
#  'નાં',
#  'ઓ',
#  '▁આવી',
#  '▁વધુ',
#  '▁તેમના',
#  '▁અથવા',
#  '▁ઘઉં',
#  'તા',
#  '▁સુધી',
#  ':',
#  '▁સૌથી',
#  '▁બે',
#  '▁તેને',
#  '▁ઉપયોગ',
#  '▁નથી',
#  '▁કરવા',
#  'મ',
#  '▁તેની',
#  '▁કારણે',
#  'માંથી',
#  '▁પછી',
#  '▁શકે',
#  '▁ઉત્તર',
#  '્સ',
#  '▁ન',
#  '▁કર્યો',
#  '▁જેમાં',
#  '▁તથા',
#  '▁રજકો',
#  '▁જીરુ',
#  '▁જ્યારે',
#  "'",
#  '▁કર્યું',
#  's',
#  '▁ના',
#  '▁પરંતુ',
#  '▁પ્રથમ',
#  '▁તો',
#  '▁દક્ષિણ',
#  '▁નામ',
#  '▁મધ્ય',
#  '▁તેમની',
#  '▁બાદ',
#  '▁કરીને',
#  '▁આવ્યું',
#  '▁ખાતે',
#  '▁અ',
#  '▁ભારતીય',
#  '▁થયો',
#  '▁દિવેલા',
#  '▁થઈ',
#  '▁સમાવેશ',
#  'ત',
#  '▁તેમને',
#  '▁વર્ષ',
#  'મી',
#  '▁આવ્યો',
#  '▁વિસ્તારમાં',
#  '▁કરતા',
#  '▁ત્યારે',
#  '▁તેમજ',
#  '▁દરમિયાન',
#  'ડ',
#  '▁કેટલાક',
#  '▁રોજ',
#  '▁સામાન્ય',
#  'જ',
#  'મા',
#  '▁માં',
#  '▁મોટા',
#  '▁આવ્યા',
#  '▁ભાગ',
#  "▁'",
#  '▁ઉપરાંત',
#  '▁અહીં',
#  '▁શકાય',
#  '▁‘',
#  '▁the',
#  'લી',
#  'લા',
#  '▁ધરાવે',
#  'િત',
#  '▁ઓફ',
#  '▁મંદિર',
#  '▁જિલ્લાના',
#  '▁જેવા',
#  '▁સૌરાષ્ટ્ર',
#  '▁ડાંગર',
#  'આ',
#  '▁એમ',
#  'જી',
#  ';',
#  '▁ખાસ',
#  '▁પૂર્વ',
#  'ટ',
#  'ડી',
#  '▁જોવા',
#  '▁જેમ',
#  '▁પોતાના',
#  '▁રાજ્ય',
#  '▁મુજબ',
#  'પ',
#  'ય',
#  'રા',
#  'વા',
#  '▁દિવસ',
#  '▁જો',
#  'વ',
#  '’',
#  '▁મળે',
#  '▁રહે',
#  '▁વગેરે',
#  '▁વચ્ચે',
#  'ઝ',
#  'રી',
#  '▁વિવિધ',
#  '▁કામ',
#  '▁સમય',
#  '▁થયા',
#  '▁મગફળી',
#  '▁તેમાં',
#  'ડા',
#  '▁તલ',
#  '▁કોઈ',
#  '▁ધ',
#  '▁થયું',
#  '▁થઇ',
#  '▁ચણા',
#  '▁વસ્તી',
#  'ળ',
#  '▁જાય',
#  '▁ગુજરાતી',
#  '/',
#  '▁અલગ',
#  '▁મકાઈ',
#  '▁ત્રણ',
#  '▁શહેર',
#  '▁ઘણા',
#  '▁તાલુકા',
#  '▁શરૂ',
#  '▁આવેલ',
#  'ણ',
#  '▁સામે',
#  'વી',
#  'બ',
#  'શ',
#  '▁બીજા',
#  '▁ધરાવતા',
#  'ગ',
#  '▁of',
#  '▁ત્યાં',
#  '▁કરવાની',
#  '▁ઇ',
#  'કા',
#  '▁દિવેલી',
#  '▁તેનો',
#  '▁બી',
#  '▁પોતાની',
#  '▁ફિલ્મ',
#  '▁સ',
#  '▁બની',
#  '▁ઉપર',
#  '▁કર્યા',
#  '▁થી',
#  '▁ઈ',
#  'ઇ',
#  '▁આપવામાં',
#  '▁ઘણી',
#  '▁ભારતના',
#  '▁જન્મ',
#  'સી',
#  'િક',
#  '▁મે',
#  '▁૬',
#  '▁નદી',
#  '▁વધારે',
#  '▁તરફ',
#  '▁કરતાં',
#  'ું',
#  '▁તુવર',
#  'ુ',
#  'તી',
#  '▁ગયા',
#  '▁છતાં',
#  '▁માત્ર',
#  'દ',
#  '▁હેઠળ',
#  '▁હતાં',
#  '▁આવેલી',
#  '▁કારણ',
#  '▁આદિવાસી',
#  'ીય',
#  '▁દર',
#  '▁તેણે',
#  '▁in',
#  '▁તેનું',
#  'કો',
#  '▁સમયે',
#  '▁લગભગ',
#  '▁મળી',
#  'ઈ',
#  '▁ટકા',
#  'પુર',
#  '▁તમામ',
#  '▁દરેક',
#  '%',
#  '▁શાકભાજી',
#  '▁વખત',
#  '▁ભાષા',
#  'હ',
#  '▁જ્યાં',
#  '▁મેળવી',
#  '▁આપી',
#  '▁વિસ્તાર',
#  'િ',
#  '▁અભ્યાસ',
#  '▁રહી',
#  'િંગ',
#  '▁રહ્યા',
#  '▁મૂળ',
#  '▁નજીક',
#  '▁જેને',
#  '▁જોકે',
#  'ોમાં',
#  '▁પાસે',
#  '▁કોઇ',
#  '▁ખૂબ',
#  '▁૧૦',
#  '▁રાષ્ટ્રીય',
#  '▁જાહેર',
#  '▁રચના',
#  '▁હોવા',
#  '▁ચાર',
#  '▁પ્રમાણે',
#  '▁“',
#  '▁and',
#  'ંગ',
#  '▁બહાર',
#  'રો',
#  '▁સેવા',
#  '▁અનેક',
#  'મો',
#  '▁સ્થાપના',
#  '▁શબ્દ',
#  '્યા',
#  '▁યુદ્ધ',
#  '▁બંને',
#  '▁દૂર',
#  '▁આપે',
#  '▁પાંચ',
#  '▁મોટી',
#  'ફ',
#  'ચ',
#  '્',
#  '▁પહેલા',
#  '▁વરિયાળી',
#  '•',
#  'યા',
#  '▁મૃત્યુ',
#  'અ',
#  'િયા',
#  '▁વિ',
#  '▁યુ',
#  'ટી',
#  '▁એટલે',
#  '▁પરથી',
#  '▁અનુસાર',
#  '▁મથક',
#  '2',
#  'સા',
#  '▁નવા',
#  'એસ',
#  '▁વિકાસ',
#  '▁સરકાર',
#  'ોને',
#  '▁દિવસે',
#  '▁૧૧',
#  '▁અંગે',
#  '▁કંપની',
#  '▁રાજા',
#  '▁સ્થાન',
#  'a',
#  '્યો',
#  '▁ધર્મ',
#  'કે',
#  '▁નીચે',
#  '▁કાર્ય',
#  '▁પ્રદેશ',
#  '▁એવી',
#  'બી',
#  '▁સ્થળ',
#  'ed',
#  '▁શિક્ષણ',
#  '▁આમ',
#  '▁બંધ',
#  '▁લે',
#  '▁અસર',
#  '▁વિશ્વ',
#  '▁૯',
#  '▁જીવન',
#  '▁માર્ગ',
#  '▁બનાવવામાં',
#  '▁પાણી',
#  '▁દેશ',
#  'વે',
#  '▁કહેવાય',
#  'તો',
#  '▁કેન્દ્ર',
#  '▁નહીં',
#  '▁તમાકુ',
#  '▁હોવાથી',
#  '▁શરૂઆત',
#  'પુરા',
#  '▁શેરડી',
#  '▁જેવાં',
#  '▁સુ',
#  '▁પડે',
#  '▁ઉત્પાદન',
#  'રે',
#  '▁a',
#  '▁એવું',
#  '▁સમગ્ર',
#  '▁નાના',
#  'થ',
#  '”',
#  'પી',
#  '▁ભારતમાં',
#  '▁કહે',
#  '▁પ્રાપ્ત',
#  '▁ઉપલબ્ધ',
#  '▁આધારિત',
#  '▁લેવામાં',
#  '▁દિશામાં',
#  '▁મદદ',
#  'પર',
#  '▁કેટલીક',
#  '▁આગળ',
#  'લે',
#  '▁૧',
#  '▁કા',
#  '▁૧૪',
#  '▁to',
#  '▁રાજ',
#  '▁વ્યક્તિ',
#  '▁જિલ્લો',
#  '▁18',
#  '▁શ્રી',
#  '▁અર્થ',
#  '▁સુરત',
#  'ધ',
#  '▁છ',
#  '▁નિર્માણ',
#  '▁૫',
#  'બા',
#  '▁પ્રાચીન',
#  '▁૮',
#  '▁યુનાઇટેડ',
#  '▁અમુક',
#  '▁પ્રકારના',
#  '▁મા',
#  '▁જમીન',
#  '▁લેખ',
#  '▁માહિતી',
#  'ીયા',
#  '▁વસે',
#  'ખ',
#  '▁સમયમાં',
#  'વિ',
#  '▁આવતા',
#  '▁કો',
#  '▁સ્થાનિક',
#  '▁પાન',
#  '▁સાહિત્ય',
#  '▁ભગવાન',
#  'ન્ટ',
#  'લો',
#  '▁રજૂ',
#  '▁મ',
#  'નુ',
#  '▁પહેલાં',
#  '▁બીજી',
#  'દા',
#  'સ્',
#  '▁બન્યા',
#  '▁હવે',
#  'જે',
#  '▁કેળાં',
#  '▁બ',
#  '▁ક્ષેત્ર',
#  '▁પ્રમાણમાં',
#  '▁ત્યાર',
#  '▁સમાન',
#  '▁હિંદુ',
#  '▁તેવી',
#  '▁એન્ડ',
#  '▁અમદાવાદ',
#  '▁તેવા',
#  '▁કિ',
#  'ોની',
#  '▁નગર',
#  '▁પ્ર',
#  '▁રંગ',
#  '▁સે',
#  '▁તેથી',
#  '▁અહીંના',
#  '▁લોકોની',
#  '્ય',
#  '▁આધુનિક',
#  '▁ઓછા',
#  '▁વડે',
#  '▁આશરે',
#  '▁તેમનું',
#  '▁બનાવવા',
#  '▁પૈકી',
#  'ડો',
#  '▁મગ',
#  'ાઈ',
#  '▁જુવાર',
#  '▁પ્રક્રિયા',
#  '▁નવી',
#  'ીંગ',
#  'e',
#  '▁પુત્ર',
#  '▁તેમનો',
#  '▁વ',
#  '▁મહત્વ',
#  '▁તૈયાર',
#  '▁૧૮',
#  '▁ખેત',
#  'd',
#  '▁જેના',
#  '▁જરૂર',
#  '▁વધારો',
#  '▁રાજ્યમાં',
#  '▁હાથ',
#  '▁બ્રિટિશ',
#  '▁લગ્ન',
#  '▁યોગ્ય',
#  '▁આપ્યો',
#  '▁સગવડ',
#  'જા',
#  '▁અંગ્રેજી',
#  '▁-',
#  '▁કચ્છ',
#  '▁અત્યંત',
#  '▁1',
#  '▁સંગીત',
#  '▁માનવ',
#  '▁થતો',
#  '▁શાસન',
#  '▁કાર્યો',
#  '▁માનવામાં',
#  '▁પોતાનું',
#  'ટા',
#  '▁નોકરી',
#  '1',
#  '▁પ્રદેશમાં',
#  '▁ચોક્કસ',
#  'વો',
#  '▁દેવ',
#  '▁અંત',
#  '▁ચાલુ',
#  '▁જિલ્લાનું',
#  'સે',
#  'કી',
#  'તે',
#  '▁વખતે',
#  '▁શોધ',
#  '▁આંતરરાષ્ટ્રીય',
#  '▁સામાજિક',
#  '▁૭',
#  '▁ગયો',
#  '▁ત્યારબાદ',
#  '▁આપ્યું',
#  '▁સુધારો',
#  '▁વડોદરા',
#  '▁જંગલ',
#  '▁પ',
#  '▁પ્રકારની',
#  '▁પદ્ધતિ',
#  'કર',
#  '▁શક્કરીયાં',
#  '▁ઓળખાય',
#  'ing',
#  '▁ઉલ્લેખ',
#  'વામાં',
#  '▁વિશાળ',
#  '▁પી',
#  '▁રહ્યો',
#  'વાળા',
#  '▁ઓ',
#  'સર',
#  '▁સંખ્યા',
#  '▁લોકપ્રિય',
#  '▁પિતા',
#  '▁ભૂમિકા',
#  '▁દરમ્યાન',
#  '▁આવેલો',
#  '▁ઓછી',
#  '▁સી',
#  'y',
#  'ર્સ',
#  '5',
#  '▁બટાટા',
#  '▁મુંબઈ',
#  '▁વાત',
#  'C',
#  '▁પૂરી',
#  '▁કર',
#  '્યુ',
#  '▁પ્રકાશિત',
#  '▁રાજકીય',
#  '▁રહ્યું',
#  '▁માતા',
#  'કાર',
#  '▁જેથી',
#  '▁૩',
#  'નિ',
#  '▁ફરી',
#  '▁બધા',
#  '▁ઉચ્ચ',
#  'વર',
#  '▁૪',
#  'ોએ',
#  '▁બને',
#  '▁હોવાનું',
#  '▁પૂર્ણ',
#  '▁જાણીતા',
#  'M',
#  '▁શહેરમાં',
#  'ોના',
#  '▁રામ',
#  '▁બનાસકાંઠા',
#  'ન્સ',
#  '▁પુસ્તક',
#  '▁ઘણાં',
#  '્યું',
#  '▁કરતી',
#  '▁૨',
#  '▁દિલ્હી',
#  '▁મહારાષ્ટ્ર',
#  'વાદ',
#  '▁ડુંગરા',
#  '▁વસવાટ',
#  '▁પુરસ્કાર',
#  '▁ડી',
#  '▁ઉદાહરણ',
#  'ણા',
#  '▁સત્તા',
#  '▁વર્ષની',
#  'o',
#  '▁અમેરિકન',
#  '▁સ્થિત',
#  '▁થયેલ',
#  '▁સુધીમાં',
#  '▁ઘર',
#  '▁ભાવનગર',
#  '▁વ્યવસ્થા',
#  '▁ચા',
#  '▁આર્થિક',
#  '▁વિશે',
#  '▁આદિવાસીઓ',
#  'યુ',
#  '▁રોગ',
#  '▁નામના',
#  '▁વાર',
#  'p',
#  '▁થતા',
#  'વું',
#  '▁જૈન',
#  '▁10',
#  '▁એવો',
#  'ઉ',
#  '▁વર્ષે',
#  '▁ધાર્મિક',
#  '▁પાડે',
#  '▁બિન',
#  '▁કરવાનો',
#  '▁નક્કી',
#  'માન',
#  '▁થતી',
#  'c',
#  '▁2008',
#  '4',
#  '▁થયેલા',
#  '▁ઓળખવા',
#  '▁હાલમાં',
#  '▁2',
#  '▁મોટો',
#  '▁પસાર',
#  '’,',
#  '▁કલા',
#  '▁સમાજ',
#  '▁વ્યવસાયમાં',
#  '▁રહેલા',
#  '▁બહુ',
#  '▁જાન્યુઆરી',
#  'ખા',
#  '▁ધ્યાન',
#  '▁સિ',
#  '▁ધરાવતી',
#  '▁નિ',
#  '▁2007',
#  '▁વર્ષના',
#  '▁સંશોધન',
#  'ણી',
#  'મે',
#  '▁યુનિવર્સિટી',
#  'ઓને',
#  'લિ',
#  '▁કહ્યું',
#  '▁આવતી',
#  '▁પડી',
#  '▁ઉ',
#  '▁સિવાય',
#  '▁લાંબા',
#  '▁ગો',
#  '▁લીધે',
#  '▁રે',
#  '▁નોંધપાત્ર',
#  '▁લેવા',
#  '▁અંદર',
#  'n',
#  '▁પ્રમુખ',
#  '▁સંપૂર્ણ',
#  '▁સાત',
#  'ગા',
#  '▁મોટું',
#  '▁લઈ',
#  '▁બોલી',
#  '▁યોજના',
#  'ભ',
#  '▁હે',
#  '▁આપવા',
#  '▁15',
#  '▁સ્વરૂપ',
#  '°',
#  'યો',
#  '▁આજે',
#  'ઘ',
#  'ડે',
#  '▁જણાવ્યું',
#  '▁વે',
#  'ઠ',
#  'તિ',
#  '▁રાજકોટ',
#  '▁એપ્રિલ',
#  '▁પ્રખ્યાત',
#  '▁જેટલા',
#  '▁20',
#  '▁ભાગના',
#  '▁સદી',
#  'શે',
#  '▁ક્ષમતા',
#  '▁કી',
#  't',
#  '▁પ્રમાણ',
#  '▁ઇતિહાસ',
#  '▁નેટવર્ક',
#  '▁સતત',
#  '▁આસપાસ',
#  '▁લીધો',
#  '▁જેઓ',
#  '▁સંગ્રહ',
#  '▁સ્તર',
#  '▁જેટલી',
#  '▁પ્રવેશ',
#  '▁16',
#  '▁રાખવામાં',
#  '▁નામે',
#  '▁સભ્ય',
#  '▁સૂર્ય',
#  '▁સૈનિકો',
#  '▁17',
#  '▁is',
#  '▁વિચાર',
#  '▁જરૂરી',
#  'દાર',
#  '▁બાળકો',
#  'વાડા',
#  '▁3',
#  '▁ભાગે',
#  'ીઓ',
#  '▁ઉપ',
#  'er',
#  '▁સ્ટેટ્સ',
#  'લાલ',
#  '▁ક્રિકેટ',
#  '▁સ્ટેશન',
#  'al',
#  '▁સપાટી',
#  ')',
#  '▁થોડા',
#  '▁ગયું',
#  '▁સંસ્કૃતિ',
#  '▁પૃથ્વી',
#  'સ્ટ',
#  '▁સો',
#  '▁બનાવી',
#  'ઠી',
#  '▁કહેવામાં',
#  '▁પ્રસિદ્ધ',
#  'ર્',
#  '."',
#  '▁શ્રેષ્ઠ',
#  '▁ફક્ત',
#  'ેલા',
#  '▁વિભાગ',
#  '▁જેનો',
#  'ૂ',
#  '▁કરવાનું',
#  '▁સંસ્થા',
#  '▁સં',
#  '▁સ્',
#  '▁સદીના',
#  '▁સફળ',
#  'ાઇ',
#  'તર',
#  'ીક',
#  '▁સ્વતંત્રતા',
#  '▁કવિ',
#  '▁ઐતિહાસિક',
#  '▁સંયુક્ત',
#  '▁પિયત',
#  '▁દેશોમાં',
#  '▁લોકોને',
#  '▁આધારે',
#  'બે',
#  'ઓમાં',
#  '▁આયોજન',
#  '▁રેલ્વે',
#  '▁at',
#  '▁૧૭',
#  '▁આધાર',
#  '▁સપ્ટેમ્બર',
#  'ગો',
#  '▁ત',
#  '▁દા',
#  '▁લીધી',
#  '▁ક',
#  '▁સર',
#  '▁ગાંધી',
#  '▁પ્રેમ',
#  '▁કામગીરી',
#  '▁જાહેરાત',
#  '▁પા',
#  '▁હ',
#  '▁મહા',
#  '▁દે',
#  '▁વી',
#  'મિ',
#  '▁ડિસેમ્બર',
#  '▁સામેલ',
#  '▁જ્ઞાન',
#  '▁ડિ',
#  '▁રસ',
#  '▁થવા',
#  '▁પ્રતિ',
#  '▁મીટર',
#  '▁રમત',
#  '▁મુ',
#  '▁નવેમ્બર',
#  'તું',
#  'b',
#  '▁માર્ચ',
#  '▁વર્ષો',
#  '▁રાજધાની',
#  '▁સ્થિતિ',
#  '▁જૂન',
#  '▁લા',
#  '▁ડે',
#  '▁કમ્પ્યુટર',
#  '▁અરવલ્લી',
#  '▁૧૫',
#  '▁નાની',
#  '▁દર્શાવે',
#  '▁કાયદા',
#  'સો',
#  '▁not',
#  'ગઢ',
#  '▁પરિણામે',
#  '▁ટીમ',
#  '▁પરંપરાગત',
#  '▁80',
#  '▁વર્ણન',
#  '▁સંચાલન',
#  'રુ',
#  '▁ન્યૂ',
#  '▁અગાઉ',
#  '▁ભારે',
#  'ેલી',
#  '▁2009',
#  '▁જોઈએ',
#  '▁લોક',
#  '▁નવ',
#  '3',
#  '▁સમુદ્ર',
#  '▁કાઢી',
#  '▁સંબંધ',
#  '▁સદીમાં',
#  '▁મહ',
#  '0',
#  '▁કોલેજ',
#  '▁લાખ',
#  '▁પાછળ',
#  '▁જતા',
#  'રામ',
#  '▁તળાવ',
#  '▁છોટાઉદેપુર',
#  'ન્',
#  'l',
#  'f',
#  'u',
#  'કુ',
#  '▁વિજય',
#  '▁રિ',
#  '▁સહિત',
#  'સં',
#  '▁કૃષ્ણ',
#  '▁વર્લ્ડ',
#  '▁ફેબ્રુઆરી',
#  '▁વસતી',
#  '▁આવા',
#  '6',
#  'પા',
#  '▁બન્યું',
#  '▁બદલે',
#  '▁પાસેથી',
#  '▁મળ્યો',
#  '▁સરેરાશ',
#  '▁મેળવવા',
#  '▁જળ',
#  '▁પ્રભાવ',
#  '▁માટેની',
#  '▁જોઇએ',
#  '્ડ',
#  '▁વિશેષ',
#  '▁સક્રિય',
#  'દેવ',
#  'N',
#  'એમ',
#  'ક્સ',
#  '▁સંસ્થાઓ',
#  'ઃ',
#  '▁ભારતની',
#  'ાં',
#  '▁ધી',
#  '▁શિવ',
#  '▁ડોલર',
#  '▁4',
#  '▁સૈન્ય',
#  'શી',
#  '▁દેશો',
#  '▁મિ',
#  'જો',
#  '▁લાલ',
#  'રાજ',
#  '▁ગણવા',
#  '▁ખર્ચ',
#  '▁લશ્કરી',
#  '▁સારી',
#  'દી',
#  '▁પાટણ',
#  '▁લેખક',
#  '▁રીત',
#  'ીત',
#  '▁ગઈ',
#  '▁કાર',
#  'સુ',
#  '▁રૂપે',
#  '▁કુ',
#  '▁વિરોધ',
#  'શા',
#  'i',
#  '▁પસંદગી',
#  '▁પે',
#  '▁ભ',
#  '▁વેચાણ',
#  '▁કથા',
#  '▁બ્રિટીશ',
#  'મ્',
#  '▁પસંદ',
#  '▁૧૨',
#  '▁શ્રેણી',
#  'ાત્મક',
#  '▁ફરીથી',
#  '૨',
#  '▁અમેરિકા',
#  '▁જેની',
#  '▁શરીર',
#  '▁જીવ',
#  '૦૦૦',
#  '▁અંતિમ',
#  '▁મી',
#  '▁ઉદ્યોગ',
#  '▁નામની',
#  '▁કિમી',
#  'ેશ્વર',
#  ...]

# %%
gujarati_vocab = Vocab(itos)

# %%
tokenizer = Tokenizer(tok_func=GujaratiTokenizer, lang='gu')

# %%
import numpy as np  
import pandas as pd 
import re           
import os
from bs4 import BeautifulSoup 
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# !pip install wget
import wget
import nltk
# Out:
# Requirement already satisfied: wget in /home/jazzyy/anaconda3/lib/python3.9/site-packages (3.2)

# %%
data_lm = TextLMDataBunch.from_folder(path=path, tokenizer=tokenizer, vocab=gujarati_vocab)

# %%
data_lm
# Out:
# TextLMDataBunch;
#
# Train: LabelList (22339 items)
# x: LMTextList
# ▁x x bo s,▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁મંગળ પુર ▁ભારત ▁દેશના ▁પશ્ચિમ ▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁મધ્યપૂર્વ ▁ભાગમાં ▁આવેલા ▁પંચમહાલ ▁જિલ્લામાં ▁આવેલા ▁કુલ ▁૭ ▁તાલુકાઓ ▁પૈકીના ▁એક ▁એવા ▁શહેરા ▁તાલુકામાં ▁આવેલું ▁એક ▁ગામ ▁છે . ▁મંગળ પુર ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁આ ▁ગામમાં ▁મુખ્યત્વે ▁મકાઈ , ▁બાજરી , ▁તુવર ▁તેમ ▁જ ▁શાકભાજીના ▁પાક ની ▁ખેતી ▁કરવામાં ▁આવે ▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી ▁તેમ ▁જ ▁દૂધ ની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁થયેલી ▁છે .,▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁કાન સ રીયા ▁એ ▁ભારત ▁દેશના ▁પશ્ચિમ ▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁ગીર ▁સોમનાથ ▁જિલ્લાના ▁ગીર ▁ગઢડા ▁તાલુકામાં ▁આવેલું ▁ગામ ▁છે . ▁આ ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁ગામમાં ▁મુખ્યત્વે ▁ઘઉં , ▁બાજરો , ▁કપાસ , ▁મગફળી , ▁શેરડી , ▁રજકો ▁તેમ ▁જ ▁અન્ય ▁શાકભાજીના ▁પાક ની ▁ખેતી ▁કરવામાં ▁આવે ▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી ▁તેમ ▁જ ▁દૂધ ની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁થયેલી ▁છે .,▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁મા થ ક ▁ભારતના ▁ગુજરાત ▁રાજ્યના ▁કચ્છ ▁જિલ્લાના ▁અંજાર ▁તાલુકામાં ▁આવેલું ▁એક ▁ગામ ▁છે . ▁આ ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી , ▁નોકરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁આ ▁ગામમાં ▁મુખ્યત્વે ▁મગ , ▁તલ , ▁બાજરી , ▁જુવાર , ▁રજકો ▁તેમ ▁જ ▁અન્ય ▁શાકભાજીના ▁પાક ની ▁ખેતી ▁કરવામાં ▁આવે ▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી ▁તેમ ▁જ ▁દૂધ ની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁થયેલી ▁છે . ▁ગામમાં ▁દાડમ દાદા નું ▁મંદિર ▁આવેલું ▁છે .,▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁ઢોલ ા <unk> ના ▁નેસ ▁ભારત ▁દેશના ▁પશ્ચિમ ▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁સૌરાષ્ટ્ર ▁વિસ્તારમાં ▁આવેલા ▁દેવ ભૂમિ ▁દ્વારકા ▁જિલ્લામાં ▁આવેલા ▁કુલ ▁૪ ▁તાલુકાઓ ▁પૈકીના ▁એક ▁એવા ▁ભાણવડ ▁તાલુકામાં ▁આવેલું ▁એક ▁ગામ ▁છે . ▁ઢોલ ા <unk> ના ▁નેસ ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁આ ▁ગામમાં ▁મુખ્યત્વે ▁ઘઉં , ▁જીરુ , ▁મગફળી , ▁તલ , ▁બાજરી , ▁ચણા , ▁કપાસ , ▁દિવેલા , ▁રજકો ▁તેમ ▁જ ▁અન્ય ▁શાકભાજીના ▁પાક ની ▁ખેતી ▁કરવામાં ▁આવે ▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી ▁તેમ ▁જ ▁દૂધ ની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁થયેલી ▁છે .
# y: LMLabelList
# ,,,,
# Path: /home/jazzyy/Text_Summ/language-model;
#
# Valid: LabelList (9574 items)
# x: LMTextList
# ▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁સોળ ીયા ▁ભારત ▁દેશના ▁પશ્ચિમ ▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁સૌરાષ્ટ્ર ▁વિસ્તારમાં ▁આવેલા ▁રાજકોટ ▁જિલ્લામાં ▁આવેલા ▁કોટડા - સાંગાણી ▁તાલુકા નું ▁એક ▁ગામ ▁છે . ▁આ ▁ગામમાં ▁મુખ્યત્વે ▁પટેલ ▁લોકોની ▁વસ્તી ▁રહે ▁છે . ▁સોળ ીયા ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁આંગણવાડી , ▁દવાખાનું , ▁પંચાયતઘર ▁અને ▁ દુધની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁છે . ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી , ▁પશુપાલન ▁છે , ▁ઘઉં , ▁ડાંગર , ▁બાજરો , ▁કપાસ , ▁જીરૂ , ▁મગફળી ▁અને ▁શાકભાજી ▁આ ▁ગામના ં ▁ખેત - ઉત્પાદનો ▁છે .,▁x x bo s ▁ભુ ક્તિ - મુક્તિ ▁ દાયક ▁દેવી , ▁નમ સ્ત ે ▁નમ સ્ત ે ▁સ્વા હા ▁હિંદુ ▁ધર્મ નાં ▁પૌરાણિક ▁શાસ્ત્રો માં ▁દર્શાવ્યા ▁પ્રમાણે ▁સિદ્ધિ દા ત્રી ▁એ ▁નવદુર્ગા નું ▁નવ મુ ▁સ્વરૂપ ▁છે . ▁તેમને ▁ચાર ▁ભુજ ાઓ ▁છે , ▁તેમણે ▁એક ▁હાથમાં ▁ગદા ▁અને ▁બીજા ▁હાથમાં ▁ચક્ર ▁ધારણ ▁કરેલું ▁છે . ▁ત્રીજો ▁હાથમાં ▁શંખ ▁અને ▁ચોથા ▁હાથમાં ▁કમળ ▁છે . ▁તેમ નું ▁વાહન ▁સિંહ ▁છે ▁પણ ▁મહદ ાંશ ે ▁તેઓ ને ▁કમળ ▁પર ▁બિરાજમાન ▁દર્શાવાય ▁છે . ▁નવરાત્રી ના ▁નવમા ▁દિવસે ▁નવદુર્ગા નાં ▁આ ▁સ્વરૂપ નું ▁પૂજન ▁અર્ ચન ▁કરાય ▁છે . ▁દેવી ▁સિદ્ધિ દા ત્રી ▁કે તૂ <unk> ▁સંચાલન ▁કરે ▁છે . ▁દેવી ▁ભાગ વત્ ▁પુરાણ ▁પ્રમાણે ▁બ્રહ્માંડ ની ▁શરૂઆતમાં ▁શિવ ે ▁રચના ▁માટે ▁આદિ - પરા શક્તિ ની ▁ઉપાસના ▁કરી . ▁એમ ▁માનવામાં ▁આવે ▁છે ▁કે ▁આદિ - પરા શક્તિ ▁દેહ ▁સ્વરૂપ ▁ધરાવતા ▁ન ▁હતા ▁આથી ▁આદિ - પરા શક્તિ ▁શિવ નાં ▁અર્ધ ા ▁દેહ માંથી <unk> સિદ્ધ િ દા ત્રી ’ ▁સ્વરૂપે ▁પ્રગટ ્યા . ▁આમ ▁શિવ ના ▁" અ <unk> <unk> શ્વર " ▁સ્વરૂપમાં ▁અર્ધ ો ▁દેહ ▁તે ▁દેવી ▁સિદ્ધિ દા ત્રી નો ▁દર્શાવાય ▁છે . ▁દેવી ▁સિદ્ધિ દા ત્રી ની ▁ઉપાસના ▁મનુષ્ય ▁ઉપરાંત ▁દેવ , ▁ગંધ ર્વ , ▁યક્ષ , ▁અ સૂર ▁અને ▁સિદ્ધ ▁પણ ▁કરે ▁છે . ▁ <unk> <unk> ् <unk> <unk> <unk> र <unk> <unk> <unk> <unk> ा <unk> <unk> <unk> र <unk> <unk> र <unk> र <unk> र <unk> र <unk> <unk> ▁| <unk> <unk> <unk> <unk> ा <unk> <unk> ा ▁ <unk> <unk> त् ▁ <unk> <unk> ् <unk> <unk> <unk> ा ▁ <unk> <unk> ् <unk> <unk> <unk> <unk> <unk> <unk> <unk> ▁||,▁x x bo s ▁લે ં થે નમ ▁એ ▁એક ▁રાસાયણિક ▁તત્વ ▁જેની ▁સંજ્ઞા <unk> ▁અને ▁અણુ ▁ક્રમાંક ▁ ૫૭ ▁છે . ▁આ ▁એક ▁ચ ળ ક તું ▁સફેદ ▁ધાતુ ▁તત્વ ▁છે ▁જેનો ▁સમાવે ધ ▁આવર્તન ▁કોઠા ના ▁ત્રીજા ▁સમૂહમાં ▁થયેલો ▁છે . ▁લે ં થે ના ઈડ ્ઝ ▁શ્રેણી નું ▁આ ▁પ્રથમ ▁તત્વ ▁છે . ▁અમુક ▁દુર્લભ ▁પાર્થિવ ▁ખનિજ ોમાં ▁આ ▁તત્વ ▁મળી ▁આવે ▁છે . ▁આ ▁ધાતુ ▁પ્રાય ઃ <unk> િયમ ▁અને ▁અન્ય ▁દુર્લભ ▁પાર્થિવ ▁તત્વો ઓ ▁સાથે ▁મળી ▁આવે ▁છે . ▁આ ▁પ્રસરણ શીલ , <unk> ભવન ક્ષમ ▁અને ▁મૃદુ ▁ધાતુ ▁છે . ▁આ ▁ધાતુ ને ▁હવામાં ▁ખુલ્લી ▁રાખતા ં ▁તેનું ▁ઝડપ થે એ ▁ઓક્સિડેશન ▁થાય ▁છે . ▁આ ને ▁મો ને ઝ ાઈટ ▁અને ▁બેસ્ટ ે નસ ાઈટ ▁નામની ▁ખનિજ માંથી ▁અ ટ પ ટી ▁વિવિધ ▁ સ્તરીય ▁નિષ્કર્ષ ણ ▁પ્રક્રિયા ▁દ્વારા ▁મેળવવામાં ▁આવે ▁છે . ▁લે ં થે નમ ના ▁સંયોજનો ▁ઉદ્દીપક ▁તરીકે , ▁કાંચ ની ▁બન વટ માં , ▁સ્ટુડિયો ની ▁કાર્બન ▁ લાઈટ િંગ ▁અને ▁પ્રો જેક્શન ▁માટે , ▁ લાઈટ ર ▁અને ▁ટો ર્ચ માં ▁જ ્વ લ ન <unk> ખો ▁ઉત્પન્ન ▁કરનાર ▁તત્વ ▁તરીકે , ▁ઈલેક્ટ્રોન ▁કેથોડ ▁તરીકે , ▁ સ્કી ં ટી લેટ ર ▁તરીકે ▁અને ▁અન્ય ▁ઉપયોગ ▁ધરાવે ▁છે . ▁લે ં થે નમ ▁કાર્બોનેટ ▁3 ) <unk> ▁ઉપયોગ ▁કી ડ ની ▁ ફેલ ના ▁ઈલાજ ▁માટે ▁માન્ય ▁કરાયો ▁છે . ▁સામાન્ય ▁તાપમાન ▁અને ▁દબાણ ▁વખતે ▁અવસ્થા : <unk> <unk>,▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁થાણા પી પ ળી ▁ભારત ▁દેશના ▁પશ્ચિમ ▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁સૌરાષ્ટ્ર ▁વિસ્તારના ▁જૂનાગઢ ▁જિલ્લામાં ▁આવેલા ▁વંથલી ▁તાલુકામાં ▁આવેલું ▁એક ▁ગામ ▁છે . ▁આ ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁આ ▁ગામમાં ▁મુખ્યત્વે ▁ઘઉં , ▁જીરુ , ▁મગફળી , ▁તલ , ▁બાજરી , ▁કપાસ , ▁દિવેલા , ▁રજકો , ▁લસણ ▁તેમ ▁જ ▁અન્ય ▁શાકભાજીના ▁પાક ની ▁ખેતી ▁કરવામાં ▁આવે ▁છે . ▁આ ▁ગામમાં ▁મગફળી માંથી ▁તેલ ▁કાઢવા ▁માટેના ▁બે ▁થી ▁ત્રણ ▁નાના ▁ઘા ણા ▁પણ ▁આવેલા ▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , માધ્યમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી , ▁સહકારી ▁મંડળી , ▁બેંક , ▁પોસ્ટ ▁ઓફિસ , ▁પ્રાથમિક ▁આરોગ્ય ▁કેન્દ્ર ▁તેમ ▁જ ▁દૂધ ની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁થયેલી ▁છે . ▁અને ▁તેની ▁વસ્તી ▁આશરે ▁૨૫૦૦ ▁છે . ▁અહીં ▁ધોરણ ▁૧૦ ▁સુધી ▁અભ્યાસ ▁કરવાની ▁સગવડ ▁છે . ▁પ્રાથમિક ▁શાળા નું ▁નામ ▁પે . ▁સેન્ટર ▁શાળા , ▁થાણા પી પ ળી ▁છે . ▁આ ▁ગામ ▁જુનાગઢ થી ▁૩૦ ▁કિ . મી ▁દુર ▁છે . ▁અહીં ▁આવવા ▁જવા ▁માટે ▁એસ . ટી . ▁બસ ▁તેમજ ▁છ ક્ ડો ▁રીક્ષા ▁નજીકના ▁તાલુકા ▁મથક ▁વંથલી , ▁કેશોદ ▁અને ▁જિલ્લા ▁મથક ▁જુનાગઢ થી ▁મળી ▁રહે ▁છે .  ...
# y: LMLabelList
# ,,,,
# Path: /home/jazzyy/Text_Summ/language-model;
#
# Test: None

# %%
data_lm.batch_size = 8

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી ▁તેમ ▁જ ▁દૂધ ની ▁ડેરી ▁જેવી ▁સવલતો ▁પ્રાપ્ય ▁થયેલી ▁છે . ▁x x bo s ▁ગુજરાત ▁અને ▁ભારતમાં ▁સ્થાન ▁કાન સ રીયા ▁એ ▁ભારત ▁દેશના ▁પશ્ચિમ ▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁ગીર ▁સોમનાથ ▁જિલ્લાના ▁ગીર ▁ગઢડા ▁તાલુકામાં ▁આવેલું ▁ગામ ▁છે . ▁આ ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁ગામમાં ▁મુખ્યત્વે ▁ઘઉં , ▁બાજરો , ▁કપાસ</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>▁ડેસ િઆ નો ▁ભાગ ▁બની ▁ગયુ . ▁ખનીજ ની ▁સમૃદ્ધ ▁અનામત ો ▁પ્રદેશમાં થી ▁મળી ▁આવી ▁અને ▁ખાસ ▁કરીને ▁સોના ▁તથા ▁ચાંદી ની ▁માત્રા ▁અત્યંત ▁વધારે ▁હતી . ▁જેના ▁પરિણામે ▁રોમ ે ▁આ ▁પ્રાંત નું ▁ભારે ▁સંસ્થાન ીકરણ ▁કર્યુ . ▁આનાથી ▁ગ્રામ્ય ▁લેટિન ▁આવ્યું ▁અને ▁ગહન રો મન - કરણ નો ▁દોર ▁આવ્યો ▁કે ▁જેનાથી ▁મૂળ - રો માન િયન નો ▁સમય ▁શરૂ ▁થયો . ▁આ ▁ઉપરાંત ▁ઈસ . ▁3</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>▁છે . ▁જેઠ ▁- વૈશાખ માં ▁તે ▁રોપ ાય ▁છે ▁અને ▁માગ સર - પોષ ▁માં ▁તે ▁ખોદી ▁કાઢવા માં ▁આવે ▁છે . ▁ભારતમાં ▁સર્વત્ર ▁થાય ▁છે . ▁સૂરણ માં ▁બે ▁જાત ▁હોય ▁છે : ▁એક ▁મીઠી ▁અને ▁બીજી ▁ખૂ જ લી વાળી , ખ ૂ જ લી વાળુ ▁સૂરણ ▁ખાવા થી ▁વ વળ ાટ ▁થાય ▁છે ▁અને ▁મોં ▁સૂ જી ▁જાય ▁છે . ▁આવા ▁સૂરણ નો ▁કંદ ▁લી સો</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>. ▁શહેરના ▁ઇતિહાસમાં ▁બે ▁વખત , ▁નામ ને ▁બેઇજિંગ ▁થી ▁બે ઇ પિંગ માં ▁બદલવા માં ▁આવેલું ; &lt;unk&gt; િક ▁અર્થે ▁' ઉત્તર ી ▁શાંતિ ' . ▁આ ▁પ્રથમ ▁વખત ▁મિંગ ▁સામ્રાજ્યના ▁હોંગ હુ ▁સમ્રાટ ▁હેઠળ ▁બન્યું , ▁અને ▁ફરીથી ▁1928 ▁માં ▁રીપબ્લિક ▁ઓફ ▁ચાઈના ના ▁ક્યુ ઓ મિ ન્ટે ંગ ▁સરકાર માં ▁બન્યું . ▁દરેક ▁પ્રસંગે , ▁બદલે લ ▁નામ ▁' રાજ ધા ની ' ▁ના ▁અર્થ ના ▁તત્ત્વ</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>▁ભાગમાં ▁આવેલા ▁ગુજરાત ▁રાજ્યના ▁સૌરાષ્ટ્ર ▁વિસ્તારના ▁જૂનાગઢ ▁જિલ્લામાં ▁આવેલા ▁વિસાવદર ▁તાલુકામાં ▁આવેલું ▁એક ▁ગામ ▁છે . ▁આ ▁ગામના ▁લોકોનો ▁મુખ્ય ▁વ્યવસાય ▁ખેતી , ▁ખેતમજૂરી ▁તેમ ▁જ ▁પશુપાલન ▁છે . ▁આ ▁ગામમાં ▁મુખ્યત્વે ▁ઘઉં , ▁જીરુ , ▁મગફળી , ▁તલ , ▁બાજરી , ▁કપાસ , ▁દિવેલા , ▁રજકો ▁તેમ ▁જ ▁અન્ય ▁શાકભાજીના ▁પાક ની ▁ખેતી ▁કરવામાં ▁આવે ▁છે . ▁આ ▁ગામમાં ▁પ્રાથમિક ▁શાળા , ▁પંચાયતઘર , ▁આંગણવાડી ▁તેમ ▁જ ▁દૂધ ની</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_lm.save()
